# %% [markdown]
# <a href="https://colab.research.google.com/github/praveentn/MidcurveNN/blob/master/sgd_callback_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SGD Callback
#
# Source: https://www.kaggle.com/ahsongchen/stochastic-gradient-descent-with-restarts-test

# %%
# mount google drive & set working directory
# requires auth (click on url & copy token into text box when prompted)
from google.colab import drive
drive.mount("/content/gdrive")

import os
print(os.getcwd())

os.chdir('/content/gdrive/My Drive/Colab Notebooks/MidcurveNN')
# !pwd
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content
# /content/gdrive/My Drive/Colab Notebooks/MidcurveNN

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from __future__ import absolute_import, division, print_function, unicode_literals

# !pip install tensorflow-gpu==2.0.0-alpha0
import tensorflow as tf

import time
from IPython.display import clear_output

from keras.layers import Input, Dense
from keras.models import Model
from keras import regularizers, optimizers
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam,RMSprop,SGD
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
from keras import regularizers
from keras.layers.normalization import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten,AveragePooling2D,UpSampling2D
from keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split
from random import shuffle
import PIL
import json
import sys
np.set_printoptions(threshold=sys.maxsize)
import matplotlib.pyplot as plt
import matplotlib
# matplotlib.use('TKAgg')
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# working directory
wdir = os.getcwd()
wdir
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/MidcurveNN'

# %%
# _URL = 'https://drive.google.com/uc?export=download&id=16rqDFLO__WySSQGlAht0FEj2uJZg4M9M'

# path_to_zip = tf.keras.utils.get_file('input.zip',
#                                       origin=_URL,
#                                       extract=True)

# input_data_folder = os.path.join(os.path.dirname(path_to_zip), 'input')
input_data_folder = wdir + "/data/input"
input_data_folder = wdir + "/data/images"
print("input data dir: ", input_data_folder)
# Out:
# input data dir:  /content/gdrive/My Drive/Colab Notebooks/MidcurveNN/data/images

# %%
import glob

image_paths = glob.glob(input_data_folder + '/**/*.png', recursive=True)
images = [os.path.basename(img_path) for img_path in image_paths]

print(len(images))

#images = os.listdir(input_data_folder)
images[99]
# Out:
# 2912
# 'CapI_Midcurve_mirrored_0_translated_10_-20.png'

# %%
# image dimension
imdim = 101

# %%
def read_input_image_pairs(datafolder=input_data_folder):
    profile_pngs = []
    midcurve_pngs = []
    for file in os.listdir(datafolder):
        fullpath = os.path.join(datafolder, file)
        if os.path.isdir(fullpath):
            continue
        if file.endswith(".png"):
            if file.find("Profile") != -1:
                profile_pngs.append(fullpath)
            if file.find("Midcurve") != -1:
                midcurve_pngs.append(fullpath)
    profile_pngs = sorted(profile_pngs)
    midcurve_pngs = sorted(midcurve_pngs)
    return profile_pngs,midcurve_pngs


def get_training_data(datafolder=input_data_folder):
    profile_pngs,midcurve_pngs = read_input_image_pairs(datafolder)
    
    profile_pngs_objs = [img_to_array(load_img(f, color_mode='rgba', target_size=(imdim, imdim))) for f in profile_pngs ]
    midcurve_pngs_objs = [img_to_array(load_img(f, color_mode='rgba', target_size=(imdim, imdim))) for f in midcurve_pngs]

#     profile_pngs_objs = np.array([x.reshape((1,) + x.shape) for x in profile_pngs_objs])
#     midcurve_pngs_objs = np.array([x.reshape((1,) + x.shape) for x in midcurve_pngs_objs])

    profile_pngs_gray_objs = [x[:,:,3] for x in profile_pngs_objs]
    midcurve_pngs_gray_objs =[x[:,:,3] for x in midcurve_pngs_objs]
    
#     profile_pngs_gray_objs = [np.where(x>128, 0, 1) for x in profile_pngs_gray_objs]
#     midcurve_pngs_gray_objs =[np.where(x>128, 0, 1) for x in midcurve_pngs_gray_objs]
        
    # shufle them
    zipped_profiles_midcurves = [(p,m) for p,m in zip(profile_pngs_gray_objs,midcurve_pngs_gray_objs)]
    shuffle(zipped_profiles_midcurves)
    profile_pngs_gray_objs, midcurve_pngs_gray_objs = zip(*zipped_profiles_midcurves)
    
    return profile_pngs_gray_objs, midcurve_pngs_gray_objs

# %%
profile_pngs_objs = ()
midcurve_pngs_objs = ()
shapes = os.listdir('/content/gdrive/My Drive/Colab Notebooks/MidcurveNN/data/images')

for shape in shapes:
    print(shape)
    tp, tm = get_training_data(os.path.join(input_data_folder, shape))
    profile_pngs_objs += tp
    midcurve_pngs_objs += tm
    print(len(profile_pngs_objs), len(midcurve_pngs_objs))
# Out:
# CapI
# 112 112
# Plus
# 224 224
# Iuvw
# 336 336
# Luvw
# 448 448
# SqLu
# 560 560
# Tuvw
# 672 672
# Vuvw
# 784 784
# Sm_n
# 896 896
# InvV
# 1008 1008
# Parl
# 1120 1120
# Trap
# 1232 1232
# Stik
# 1344 1344
# Usla
# 1456 1456

# %%
def plot_results(original_imgs,computed_imgs,n=10):
    # n = 10  # how many digits we will display
    plt.figure(figsize=(20, 4))
    for i in range(n):
        # display original
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(original_imgs[i].reshape(imdim, imdim),cmap='gray_r')
#         plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    
        # display reconstruction
        ax = plt.subplot(2, n, i + 1 + n)
        plt.imshow(computed_imgs[i].reshape(imdim, imdim),cmap='gray_r')
#         plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
plot_results(profile_pngs_objs[710:720],midcurve_pngs_objs[710:720])

# %%
def get_train_test_split(profile_pngs_gray_objs, midcurve_pngs_gray_objs, encoding_dim=imdim, input_dim=imdim):

    # Training
    profile_pngs_flat_objs = [x.reshape(input_dim,input_dim,1) for x in profile_pngs_gray_objs]
    midcurve_pngs_flat_objs = [x.reshape(input_dim,input_dim,1) for x in midcurve_pngs_gray_objs]
    
    profile_pngs_objs = np.array(profile_pngs_flat_objs)
    midcurve_pngs_objs= np.array(midcurve_pngs_flat_objs)
    
    '''
    train_size = int(len(profile_pngs_objs)*0.7)
    x_train = profile_pngs_objs[:train_size]
    y_train = midcurve_pngs_objs[:train_size]
    x_test = profile_pngs_objs[train_size:]
    y_test = midcurve_pngs_objs[train_size:]
    '''
    x_train, x_test, y_train, y_test = train_test_split(profile_pngs_objs, midcurve_pngs_objs, 
                                                        test_size=0.05, random_state=37)
    return x_train, x_test, y_train, y_test

# %%
x_train, x_test, y_train, y_test = get_train_test_split(profile_pngs_objs, midcurve_pngs_objs)

print((len(x_train), len(y_train)), (len(x_test), len(y_test)))
# Out:
# (1383, 1383) (73, 73)

# %%
import sys
import random
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style("white")
import time
t_start = time.time()
# %matplotlib inline

# import cv2
from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook #, tnrange
#from itertools import chain
from skimage.io import imread, imshow #, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from keras.models import Model, load_model, save_model
from keras.layers import Input,Dropout,BatchNormalization,Activation,Add, Flatten, Dense
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam, SGD
from keras import backend as K
from keras import optimizers
import tensorflow as tf
from keras.preprocessing.image import array_to_img, img_to_array, load_img,save_img

# %%
img_size_ori = 101
img_size_target = 101

def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    
def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

# %%
x_valid = x_test
y_valid = y_test

print(x_train.shape,y_train.shape,x_valid.shape,y_valid.shape)
print(np.mean(x_train),np.mean(y_train),np.std(x_train),np.std(y_train))
print(np.mean(x_valid),np.mean(y_valid),np.std(x_valid),np.std(y_valid))
print(np.max(x_train),np.max(y_train),np.max(x_valid),np.max(y_valid))
print(np.min(x_train),np.min(y_train),np.min(x_valid),np.min(y_valid))
# Out:
# (1383, 101, 101, 1) (1383, 101, 101, 1) (73, 101, 101, 1) (73, 101, 101, 1)
# 2.0304651 0.8611942 16.748983 13.421182
# 1.9104372 0.7833009 16.283833 12.386359
# 251.0 255.0 251.0 255.0
# 0.0 0.0 0.0 0.0

# %%
def BatchActivate(x):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def convolution_block(x, filters, size, strides=(1,1), padding='same', activation=True):
    x = Conv2D(filters, size, strides=strides, padding=padding)(x)
    if activation == True:
        x = BatchActivate(x)
    return x

def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = convolution_block(x, num_filters, (3,3) )
    x = convolution_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
# Build model
def build_model(input_layer, start_neurons, DropoutRatio=0.05):
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)

    # 25 -> 12
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(pool2)
    conv3 = residual_block(conv3,start_neurons * 4)
    conv3 = residual_block(conv3,start_neurons * 4, True)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(DropoutRatio)(pool3)

    # 12 -> 6
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(pool3)
    conv4 = residual_block(conv4,start_neurons * 8)
    conv4 = residual_block(conv4,start_neurons * 8, True)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(DropoutRatio)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation=None, padding="same")(pool4)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    # 6 -> 12
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(DropoutRatio)(uconv4)
    
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation=None, padding="same")(uconv4)
    uconv4 = residual_block(uconv4,start_neurons * 8)
    uconv4 = residual_block(uconv4,start_neurons * 8, True)
    
    # 12 -> 25
    #deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="valid")(uconv4)
    uconv3 = concatenate([deconv3, conv3])    
    uconv3 = Dropout(DropoutRatio)(uconv3)
    
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation=None, padding="same")(uconv3)
    uconv3 = residual_block(uconv3,start_neurons * 4)
    uconv3 = residual_block(uconv3,start_neurons * 4, True)

    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation=None, padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)

    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation=None, padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv2 = residual_block(uconv1,start_neurons * 1, True)

    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation=None)(uconv2)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

# %%
'''
def build_model(input_layer, start_neurons, DropoutRatio = 0.05):
    #input_layer = Input(shape=self.img_shape)

    # encoder
    # 101 -> 50
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(input_layer)
    conv1 = residual_block(conv1,start_neurons * 1)
    conv1 = residual_block(conv1,start_neurons * 1, True)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(DropoutRatio/2)(pool1)

    # 50 -> 25
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(pool1)
    conv2 = residual_block(conv2,start_neurons * 2)
    conv2 = residual_block(conv2,start_neurons * 2, True)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(DropoutRatio)(pool2)
    
    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation="relu", padding="same")(pool2)
    convm = residual_block(convm,start_neurons * 16)
    convm = residual_block(convm,start_neurons * 16, True)
    
    
    # decoder
    # 25 -> 50
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv2 = concatenate([deconv2, conv2])
        
    uconv2 = Dropout(DropoutRatio)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = residual_block(uconv2,start_neurons * 2)
    uconv2 = residual_block(uconv2,start_neurons * 2, True)

    # 50 -> 101
    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    
    uconv1 = Dropout(DropoutRatio)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = residual_block(uconv1,start_neurons * 1)
    uconv2 = residual_block(uconv1,start_neurons * 1, True)

    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation="relu")(uconv2)
    output_layer =  Activation('sigmoid')(output_layer_noActi)
    
    return output_layer

#    return Model(input_layer, output_layer)

'''
# Out:
# '\ndef build_model(input_layer, start_neurons, DropoutRatio = 0.05):\n    #input_layer = Input(shape=self.img_shape)\n\n    # encoder\n    # 101 -> 50\n    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(input_layer)\n    conv1 = residual_block(conv1,start_neurons * 1)\n    conv1 = residual_block(conv1,start_neurons * 1, True)\n    pool1 = MaxPooling2D((2, 2))(conv1)\n    pool1 = Dropout(DropoutRatio/2)(pool1)\n\n    # 50 -> 25\n    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(pool1)\n    conv2 = residual_block(conv2,start_neurons * 2)\n    conv2 = residual_block(conv2,start_neurons * 2, True)\n    pool2 = MaxPooling2D((2, 2))(conv2)\n    pool2 = Dropout(DropoutRatio)(pool2)\n    \n    # Middle\n    convm = Conv2D(start_neurons * 16, (3, 3), activation="relu", padding="same")(pool2)\n    convm = residual_block(convm,start_neurons * 16)\n    convm = residual_block(convm,start_neurons * 16, True)\n    \n    \n    # decoder\n    # 25 -> 50\n    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(convm)\n    uconv2 = concatenate([deconv2, conv2])\n        \n    uconv2 = Dropout(DropoutRatio)(uconv2)\n    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(uconv2)\n    uconv2 = residual_block(uconv2,start_neurons * 2)\n    uconv2 = residual_block(uconv2,start_neurons * 2, True)\n\n    # 50 -> 101\n    #deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)\n    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="valid")(uconv2)\n    uconv1 = concatenate([deconv1, conv1])\n    \n    uconv1 = Dropout(DropoutRatio)(uconv1)\n    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)\n    uconv1 = residual_block(uconv1,start_neurons * 1)\n    uconv2 = residual_block(uconv1,start_neurons * 1, True)\n\n    output_layer_noActi = Conv2D(1, (1,1), padding="same", activation="relu")(uconv2)\n    output_layer =  Activation(\'sigmoid\')(output_layer_noActi)\n    \n    return output_layer\n\n#    return Model(input_layer, output_layer)\n\n'

# %%
def get_iou_vector(A, B):
    batch_size = A.shape[0]
    metric = []
    for batch in range(batch_size):
        t, p = A[batch]>0, B[batch]>0
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) > 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) >= 1 and np.count_nonzero(p) == 0:
#             metric.append(0)
#             continue
#         if np.count_nonzero(t) == 0 and np.count_nonzero(p) == 0:
#             metric.append(1)
#             continue
        
        intersection = np.logical_and(t, p)
        union = np.logical_or(t, p)
        iou = (np.sum(intersection > 0) + 1e-10 )/ (np.sum(union > 0) + 1e-10)
        thresholds = np.arange(0.5, 1, 0.05)
        s = []
        for thresh in thresholds:
            s.append(iou > thresh)
        metric.append(np.mean(s))

    return np.mean(metric)

def my_iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

def my_iou_metric_2(label, pred):
    return tf.py_func(get_iou_vector, [label, pred >0], tf.float64)

# %%
# code download from: https://github.com/bermanmaxim/LovaszSoftmax
def lovasz_grad(gt_sorted):
    """
    Computes gradient of the Lovasz extension w.r.t sorted errors
    See Alg. 1 in paper
    """
    gts = tf.reduce_sum(gt_sorted)
    intersection = gts - tf.cumsum(gt_sorted)
    union = gts + tf.cumsum(1. - gt_sorted)
    jaccard = 1. - intersection / union
    jaccard = tf.concat((jaccard[0:1], jaccard[1:] - jaccard[:-1]), 0)
    return jaccard

def lovasz_hinge(logits, labels, per_image=True, ignore=None):
    """
    Binary Lovasz hinge loss
      logits: [B, H, W] Variable, logits at each pixel (between -\infty and +\infty)
      labels: [B, H, W] Tensor, binary ground truth masks (0 or 1)
      per_image: compute the loss per image instead of per batch
      ignore: void class id
    """
    if per_image:
        def treat_image(log_lab):
            log, lab = log_lab
            log, lab = tf.expand_dims(log, 0), tf.expand_dims(lab, 0)
            log, lab = flatten_binary_scores(log, lab, ignore)
            return lovasz_hinge_flat(log, lab)
        losses = tf.map_fn(treat_image, (logits, labels), dtype=tf.float32)
        loss = tf.reduce_mean(losses)
    else:
        loss = lovasz_hinge_flat(*flatten_binary_scores(logits, labels, ignore))
    return loss

def lovasz_hinge_flat(logits, labels):
    """
    Binary Lovasz hinge loss
      logits: [P] Variable, logits at each prediction (between -\infty and +\infty)
      labels: [P] Tensor, binary ground truth labels (0 or 1)
      ignore: label to ignore
    """
    def compute_loss():
        labelsf = tf.cast(labels, logits.dtype)
        signs = 2. * labelsf - 1.
        errors = 1. - logits * tf.stop_gradient(signs)
        errors_sorted, perm = tf.nn.top_k(errors, k=tf.shape(errors)[0], name="descending_sort")
        gt_sorted = tf.gather(labelsf, perm)
        grad = lovasz_grad(gt_sorted)
        loss = tf.tensordot(tf.nn.relu(errors_sorted), tf.stop_gradient(grad), 1, name="loss_non_void")
        return loss

    # deal with the void prediction case (only void pixels)
    loss = tf.cond(tf.equal(tf.shape(logits)[0], 0),
                   lambda: tf.reduce_sum(logits) * 0.,
                   compute_loss,
                   strict=True,
                   name="loss"
                   )
    return loss

def flatten_binary_scores(scores, labels, ignore=None):
    """
    Flattens predictions in the batch (binary case)
    Remove labels equal to 'ignore'
    """
    scores = tf.reshape(scores, (-1,))
    labels = tf.reshape(labels, (-1,))
    if ignore is None:
        return scores, labels
    valid = tf.not_equal(labels, ignore)
    vscores = tf.boolean_mask(scores, valid, name='valid_scores')
    vlabels = tf.boolean_mask(labels, valid, name='valid_labels')
    return vscores, vlabels

def lovasz_loss(y_true, y_pred):
    y_true, y_pred = K.cast(K.squeeze(y_true, -1), 'int32'), K.cast(K.squeeze(y_pred, -1), 'float32')
    #logits = K.log(y_pred / (1. - y_pred))
    logits = y_pred #Jiaxin
    loss = lovasz_hinge(logits, y_true, per_image = True, ignore = None)
    return loss

# %%
#Implementation
#Both finding the optimal range of learning rates and assigning a learning rate schedule can be implemented quite trivially using Keras Callbacks.
#Finding the optimal learning rate range
#We can write a Keras Callback which tracks the loss associated with a learning rate varied linearly over a defined range.
from keras.callbacks import Callback
import matplotlib.pyplot as plt

class LRFinder(Callback):
    
    '''
    A simple callback for finding the optimal learning rate range for your model + dataset. 
    
    # Usage
        ```python
            lr_finder = LRFinder(min_lr=1e-5, 
                                 max_lr=1e-2, 
                                 steps_per_epoch=np.ceil(epoch_size/batch_size), 
                                 epochs=3)
            model.fit(X_train, Y_train, callbacks=[lr_finder])
            
            lr_finder.plot_loss()
        ```
    
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        epochs: Number of epochs to run experiment. Usually between 2 and 4 epochs is sufficient. 
        
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: https://arxiv.org/abs/1506.01186
    '''

    def __init__(self, min_lr=1e-5, max_lr=1e-2, steps_per_epoch=None, epochs=None):
        super().__init__()
        
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.total_iterations = steps_per_epoch * epochs
        self.iteration = 0
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        x = self.iteration / self.total_iterations 
        return self.min_lr + (self.max_lr-self.min_lr) * x
        
    def on_train_begin(self, logs=None):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.min_lr)
        
    def on_batch_end(self, epoch, logs=None):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.iteration += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.iteration)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
            
        K.set_value(self.model.optimizer.lr, self.clr())
    
    def plot_lr(self):
        '''Helper function to quickly inspect the learning rate schedule.'''
        plt.plot(self.history['iterations'], self.history['lr'])
        plt.yscale('log')
        plt.xlabel('Iteration')
        plt.ylabel('Learning rate')
        
    def plot_loss(self):
        '''Helper function to quickly observe the learning rate experiment results.'''
        plt.plot(self.history['lr'], self.history['loss'])
        plt.xscale('log')
        plt.xlabel('Learning rate')
        plt.ylabel('Loss')

# %%
from keras.callbacks import Callback
import keras.backend as K
import numpy as np

class SGDRScheduler(Callback):
    '''Cosine annealing learning rate scheduler with periodic restarts.
    # Usage
        ```python
            schedule = SGDRScheduler(min_lr=1e-5,
                                     max_lr=1e-2,
                                     steps_per_epoch=np.ceil(epoch_size/batch_size),
                                     lr_decay=0.9,
                                     cycle_length=5,
                                     mult_factor=1.5)
            model.fit(X_train, Y_train, epochs=100, callbacks=[schedule])
        ```
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        lr_decay: Reduce the max_lr after the completion of each cycle.
                  Ex. To reduce the max_lr by 20% after each cycle, set this value to 0.8.
        cycle_length: Initial number of epochs in a cycle.
        mult_factor: Scale epochs_to_restart after each full cycle completion.
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: http://arxiv.org/abs/1608.03983
    '''
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay
        self.batch_since_restart = 0
        self.next_restart = cycle_length
        self.steps_per_epoch = steps_per_epoch
        self.cycle_length = cycle_length
        self.mult_factor = mult_factor
        self.history = {}
        
    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        K.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        self.batch_since_restart += 1
        K.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()
            
    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# %%
x_trn, x_val, y_trn, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=79)
print(x_trn.shape,y_trn.shape,x_val.shape,y_val.shape)
print(x_train.shape,y_train.shape,x_valid.shape,y_valid.shape)
# Out:
# (1106, 101, 101, 1) (1106, 101, 101, 1) (277, 101, 101, 1) (277, 101, 101, 1)
# (1383, 101, 101, 1) (1383, 101, 101, 1) (73, 101, 101, 1) (73, 101, 101, 1)

# %%
# LR Search -- ResUnet with binary_crossentropy loss
mt1 = time.time()
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16, 0.5)
model = Model(input_layer, output_layer)

reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode='max', factor=0.5, patience=3, min_lr=0.00001, verbose=1)

epochs = 5
batch_size = 5
epoch_size = len(x_trn)
lr=0.01
lr_finder = LRFinder(min_lr=1e-5, 
                    max_lr=1e-2, 
                    steps_per_epoch=np.ceil(epoch_size/batch_size), 
                    epochs=epochs)

#optimizer = SGD(lr=lr, momentum=0.8, decay=0.001, nesterov=False)
optimizer = optimizers.adam(lr = lr)
model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=[my_iou_metric])

history = model.fit(x_trn, y_trn,
                    validation_data=[x_val, y_val], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[lr_finder,reduce_lr], 
                    verbose=2)
lr_finder.plot_loss()
mt2 = time.time()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0817 17:14:53.757163 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0817 17:14:53.779935 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0817 17:14:53.784395 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0817 17:14:53.812722 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0817 17:14:53.813509 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0817 17:14:54.543753 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0817 17:14:55.052665 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0817 17:14:55.061482 140186619828096 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0817 17:14:59.029454 140186619828096 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0817 17:14:59.042524 140186619828096 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0817 17:14:59.061763 140186619828096 deprecation.py:323] From <ipython-input-20-8315fceab778>:28: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
# Train on 1106 samples, validate on 277 samples
# Epoch 1/5
#  - 22s - loss: -9.2130e+00 - my_iou_metric: 0.0000e+00 - val_loss: -5.5365e+00 - val_my_iou_metric: 0.0000e+00
# Epoch 2/5
#  - 14s - loss: -1.2778e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3033e+01 - val_my_iou_metric: 0.0000e+00
# Epoch 3/5
#  - 14s - loss: -1.2871e+01 - my_iou_metric: 0.0000e+00 - val_loss: 0.1074 - val_my_iou_metric: 3.6101e-04
# Epoch 4/5
#  - 14s - loss: -1.2852e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3533e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.004000999964773655.
# Epoch 5/5
#  - 14s - loss: -1.2804e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3819e+01 - val_my_iou_metric: 0.0000e+00

# %%
encoded_imgs = model.predict(x_val)
decoded_imgs = model.predict(encoded_imgs)

plot_results(x_val, decoded_imgs)

# %%
version = 1.2
basic_name = f'LR_midsurface_v{version}'
save_model_name = basic_name + '.model'
submission_file = basic_name + '.csv'

print(save_model_name)
print(submission_file)
# Out:
# LR_midsurface_v1.2.model
# LR_midsurface_v1.2.csv

# %%
# Test1-1 -- ResUnet with binary_crossentropy loss
# With cosine annealing learning rate scheduler with periodic restarts

mt1 = time.time()
save_model_name = basic_name + '.model1'
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.25)
model = Model(input_layer, output_layer)

model_checkpoint = ModelCheckpoint(save_model_name,monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.0001, verbose=1)

epochs = 30
batch_size = 5
epoch_size = len(x_trn)
lr=0.01
schedule = SGDRScheduler(min_lr=1e-4,
                        max_lr=1e-2,
                        steps_per_epoch=np.ceil(epoch_size/batch_size),
                        lr_decay=0.9,
                        cycle_length=5,
                        mult_factor=1.5)

#optimizer = SGD(lr=lr, momentum=0.8, decay=0.001, nesterov=False)
optimizer = optimizers.adam(lr = lr)
model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=[my_iou_metric])

history = model.fit(x_trn, y_trn,
                    validation_data=[x_val, y_val], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[schedule,reduce_lr, model_checkpoint], 
                    verbose=2)
mt2 = time.time()
print(f"Test1-1 {epochs,batch_size} runtime = {(mt2-mt1)/60} mins")
print("Evaluation on X_valid:", model.evaluate(x_valid, y_valid))
# Out:
# Train on 1106 samples, validate on 277 samples
# Epoch 1/30
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.174493). Check your callbacks.
#   % delta_t_median)
#  - 21s - loss: -1.2412e+01 - my_iou_metric: 0.0000e+00 - val_loss: -9.7138e+00 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00001: my_iou_metric improved from -inf to 0.00000, saving model to LR_midsurface_v1.2.model1
# Epoch 2/30
#  - 14s - loss: -1.2754e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.2923e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00002: my_iou_metric did not improve from 0.00000
# Epoch 3/30
#  - 14s - loss: -1.2857e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.2670e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00003: my_iou_metric did not improve from 0.00000
# Epoch 4/30
#  - 14s - loss: -1.2987e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3889e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005226829671300948.
#
# Epoch 00004: my_iou_metric did not improve from 0.00000
# Epoch 5/30
#  - 14s - loss: -1.3012e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3826e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00005: my_iou_metric did not improve from 0.00000
# Epoch 6/30
#  - 14s - loss: -1.2893e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3333e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00006: my_iou_metric did not improve from 0.00000
# Epoch 7/30
#  - 14s - loss: -1.2956e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3729e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0038483126554638147.
#
# Epoch 00007: my_iou_metric did not improve from 0.00000
# Epoch 8/30
#  - 14s - loss: -1.2912e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.2745e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00008: my_iou_metric did not improve from 0.00000
# Epoch 9/30
#  - 14s - loss: -1.2901e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3823e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00009: my_iou_metric did not improve from 0.00000
# Epoch 10/30
#  - 14s - loss: -1.3033e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3897e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0014235293492674828.
#
# Epoch 00010: my_iou_metric did not improve from 0.00000
# Epoch 11/30
#  - 14s - loss: -1.3076e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3931e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00011: my_iou_metric did not improve from 0.00000
# Epoch 12/30
#  - 14s - loss: -1.3089e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3906e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00012: my_iou_metric did not improve from 0.00000
# Epoch 13/30
#  - 14s - loss: -1.3104e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3935e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00013: my_iou_metric did not improve from 0.00000
# Epoch 14/30
#  - 14s - loss: -1.3015e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3919e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.003981851506978273.
#
# Epoch 00014: my_iou_metric did not improve from 0.00000
# Epoch 15/30
#  - 14s - loss: -1.3006e+01 - my_iou_metric: 9.0416e-05 - val_loss: -1.3404e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00015: my_iou_metric improved from 0.00000 to 0.00009, saving model to LR_midsurface_v1.2.model1
# Epoch 16/30
#  - 22s - loss: -1.3049e+01 - my_iou_metric: 1.8083e-04 - val_loss: -1.3783e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00016: my_iou_metric improved from 0.00009 to 0.00018, saving model to LR_midsurface_v1.2.model1
# Epoch 17/30
#  - 25s - loss: -1.3052e+01 - my_iou_metric: 9.0416e-05 - val_loss: -1.3913e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00017: my_iou_metric did not improve from 0.00018
# Epoch 18/30
#  - 25s - loss: -1.3123e+01 - my_iou_metric: 6.3291e-04 - val_loss: -1.3987e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00018: my_iou_metric improved from 0.00018 to 0.00063, saving model to LR_midsurface_v1.2.model1
# Epoch 19/30
#  - 21s - loss: -1.3158e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.4002e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00019: my_iou_metric did not improve from 0.00063
# Epoch 20/30
#  - 14s - loss: -1.3184e+01 - my_iou_metric: 7.2333e-04 - val_loss: -1.4024e+01 - val_my_iou_metric: 3.6101e-04
#
# Epoch 00020: my_iou_metric improved from 0.00063 to 0.00072, saving model to LR_midsurface_v1.2.model1
# Epoch 21/30
#  - 14s - loss: -1.3195e+01 - my_iou_metric: 6.3291e-04 - val_loss: -1.4027e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0010499999625608325.
#
# Epoch 00021: my_iou_metric did not improve from 0.00072
# Epoch 22/30
#  - 14s - loss: -1.3211e+01 - my_iou_metric: 0.0016 - val_loss: -1.4054e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00022: my_iou_metric improved from 0.00072 to 0.00163, saving model to LR_midsurface_v1.2.model1
# Epoch 23/30
#  - 14s - loss: -1.3223e+01 - my_iou_metric: 0.0024 - val_loss: -1.4050e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00023: my_iou_metric improved from 0.00163 to 0.00244, saving model to LR_midsurface_v1.2.model1
# Epoch 24/30
#  - 14s - loss: -1.3228e+01 - my_iou_metric: 0.0014 - val_loss: -1.4067e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00024: my_iou_metric did not improve from 0.00244
# Epoch 25/30
#  - 14s - loss: -1.3233e+01 - my_iou_metric: 0.0016 - val_loss: -1.4065e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00025: my_iou_metric did not improve from 0.00244
# Epoch 26/30
#  - 14s - loss: -1.3180e+01 - my_iou_metric: 9.9458e-04 - val_loss: -1.4045e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0036176920402795076.
#
# Epoch 00026: my_iou_metric did not improve from 0.00244
# Epoch 27/30
#  - 14s - loss: -1.3164e+01 - my_iou_metric: 9.9458e-04 - val_loss: -1.3987e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00027: my_iou_metric did not improve from 0.00244
# Epoch 28/30
#  - 14s - loss: -1.3207e+01 - my_iou_metric: 0.0017 - val_loss: -1.4065e+01 - val_my_iou_metric: 0.0094
#
# Epoch 00028: my_iou_metric did not improve from 0.00244
# Epoch 29/30
#  - 14s - loss: -1.3212e+01 - my_iou_metric: 0.0016 - val_loss: -1.4054e+01 - val_my_iou_metric: 3.6101e-04
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0032244648318737745.
#
# Epoch 00029: my_iou_metric did not improve from 0.00244
# Epoch 30/30
#  - 14s - loss: -1.3202e+01 - my_iou_metric: 0.0025 - val_loss: -1.3898e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00030: my_iou_metric improved from 0.00244 to 0.00253, saving model to LR_midsurface_v1.2.model1
# Test1-1 (30, 5) runtime = 8.8105965813001 mins
# 73/73 [==============================] - 0s 5ms/step
# Evaluation on X_valid: [-12.132741379411254, 0.0]

# %%
encoded_imgs = model.predict(x_val)
decoded_imgs = model.predict(encoded_imgs)

plot_results(x_val, decoded_imgs)

# %%
#Test1-1 Performance
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
plt.title('ResUNet: Binary Crossentropy Loss')
ax_score.plot(history.epoch, history.history["my_iou_metric"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric"], label="Validation score")
ax_score.legend()
plt.title('Cosine annealing learning rate scheduler with periodic restarts')
# Out:
# Text(0.5, 1.0, 'Cosine annealing learning rate scheduler with periodic restarts')

# %%
save_model_name = basic_name + '.model1'

# %%
# Test1-2: continue with Lovasz Loss, LR Search
mt1 = time.time()
model = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
input_x = model.layers[0].input
output_layer = model.layers[-1].input
model = Model(input_x, output_layer)

reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=2, min_lr=0.00001, verbose=1)
epochs = 30
batch_size = 5
epoch_size = len(x_trn)
lr=0.001
lr_finder = LRFinder(min_lr=1e-5, 
                    max_lr=1e-2, 
                    steps_per_epoch=np.ceil(epoch_size/batch_size), 
                    epochs=epochs)

c = optimizers.adam(lr = lr)
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])
history = model.fit(x_trn, y_trn,
                    validation_data=[x_val, y_val], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[lr_finder,reduce_lr], 
                    verbose=2)
lr_finder.plot_loss()
mt2 = time.time()
# Out:
# Train on 1106 samples, validate on 277 samples
# Epoch 1/30
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.376234). Check your callbacks.
#   % delta_t_median)
#  - 25s - loss: 0.9352 - my_iou_metric_2: 0.0046 - val_loss: 0.5983 - val_my_iou_metric_2: 0.0264
# Epoch 2/30
#  - 15s - loss: 0.4534 - my_iou_metric_2: 0.0211 - val_loss: 0.8424 - val_my_iou_metric_2: 0.0791
# Epoch 3/30
#  - 15s - loss: 0.2135 - my_iou_metric_2: 0.0212 - val_loss: 0.1262 - val_my_iou_metric_2: 0.0303
# Epoch 4/30
#  - 16s - loss: 0.1244 - my_iou_metric_2: 0.0124 - val_loss: 0.0855 - val_my_iou_metric_2: 0.0101
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0006709999870508909.
# Epoch 5/30
#  - 16s - loss: 0.0999 - my_iou_metric_2: 0.0101 - val_loss: 0.1035 - val_my_iou_metric_2: 0.0036
# Epoch 6/30
#  - 16s - loss: 0.0715 - my_iou_metric_2: 0.0240 - val_loss: 0.0491 - val_my_iou_metric_2: 0.0220
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.001003999961540103.
# Epoch 7/30
#  - 15s - loss: 0.1369 - my_iou_metric_2: 0.0145 - val_loss: 8.0874 - val_my_iou_metric_2: 0.0112
# Epoch 8/30
#  - 16s - loss: 0.0737 - my_iou_metric_2: 0.0152 - val_loss: 0.0355 - val_my_iou_metric_2: 0.0318
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0013370000524446368.
# Epoch 9/30
#  - 16s - loss: 0.0444 - my_iou_metric_2: 0.0203 - val_loss: 0.0442 - val_my_iou_metric_2: 0.0094
# Epoch 10/30
#  - 16s - loss: 0.0391 - my_iou_metric_2: 0.0335 - val_loss: 0.0318 - val_my_iou_metric_2: 0.0253
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0016700000269338489.
# Epoch 11/30
#  - 16s - loss: 0.0351 - my_iou_metric_2: 0.0411 - val_loss: 0.0263 - val_my_iou_metric_2: 0.0661
# Epoch 12/30
#  - 16s - loss: 0.0375 - my_iou_metric_2: 0.0502 - val_loss: 0.0273 - val_my_iou_metric_2: 0.0368
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.002002999885007739.
# Epoch 13/30
#  - 16s - loss: 0.0657 - my_iou_metric_2: 0.0292 - val_loss: 0.0508 - val_my_iou_metric_2: 0.0000e+00
# Epoch 14/30
#  - 16s - loss: 0.0490 - my_iou_metric_2: 0.0227 - val_loss: 0.0501 - val_my_iou_metric_2: 0.0191
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0023360000923275948.
# Epoch 15/30
#  - 16s - loss: 0.0441 - my_iou_metric_2: 0.0405 - val_loss: 0.0467 - val_my_iou_metric_2: 0.0043
# Epoch 16/30
#  - 16s - loss: 0.0300 - my_iou_metric_2: 0.0854 - val_loss: 0.0309 - val_my_iou_metric_2: 0.0094
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.002669000066816807.
# Epoch 17/30
#  - 16s - loss: 0.0416 - my_iou_metric_2: 0.1278 - val_loss: 0.2064 - val_my_iou_metric_2: 0.0000e+00
# Epoch 18/30
#  - 16s - loss: 0.0509 - my_iou_metric_2: 0.0533 - val_loss: 0.0327 - val_my_iou_metric_2: 0.0260
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.003002000041306019.
# Epoch 19/30
#  - 16s - loss: 0.0322 - my_iou_metric_2: 0.0815 - val_loss: 0.0272 - val_my_iou_metric_2: 0.2848
# Epoch 20/30
#  - 16s - loss: 0.0294 - my_iou_metric_2: 0.1119 - val_loss: 0.0645 - val_my_iou_metric_2: 0.0000e+00
# Epoch 21/30
#  - 16s - loss: 0.0311 - my_iou_metric_2: 0.1255 - val_loss: 0.0322 - val_my_iou_metric_2: 0.0422
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.003501500003039837.
# Epoch 22/30
#  - 16s - loss: 0.0325 - my_iou_metric_2: 0.0946 - val_loss: 0.0271 - val_my_iou_metric_2: 0.1437
# Epoch 23/30
#  - 16s - loss: 0.0323 - my_iou_metric_2: 0.0944 - val_loss: 0.0342 - val_my_iou_metric_2: 0.0101
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.003834499977529049.
# Epoch 24/30
#  - 16s - loss: 0.0270 - my_iou_metric_2: 0.1382 - val_loss: 0.0213 - val_my_iou_metric_2: 0.2993
# Epoch 25/30
#  - 16s - loss: 0.0235 - my_iou_metric_2: 0.2003 - val_loss: 0.0226 - val_my_iou_metric_2: 0.2458
# Epoch 26/30
#  - 16s - loss: 0.2219 - my_iou_metric_2: 0.0723 - val_loss: 0.8940 - val_my_iou_metric_2: 0.0000e+00
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.004333999939262867.
# Epoch 27/30
#  - 16s - loss: 0.3396 - my_iou_metric_2: 0.0000e+00 - val_loss: 0.1078 - val_my_iou_metric_2: 0.0000e+00
# Epoch 28/30
#  - 16s - loss: 0.0698 - my_iou_metric_2: 2.7125e-04 - val_loss: 0.0530 - val_my_iou_metric_2: 0.0000e+00
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.004666999913752079.
# Epoch 29/30
#  - 16s - loss: 0.0525 - my_iou_metric_2: 4.5208e-04 - val_loss: 0.0412 - val_my_iou_metric_2: 0.0011
# Epoch 30/30
#  - 16s - loss: 0.0469 - my_iou_metric_2: 0.0024 - val_loss: 0.0526 - val_my_iou_metric_2: 0.0000e+00
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.

# %%
encoded_imgs = model.predict(x_val)
decoded_imgs = model.predict(encoded_imgs)

plot_results(x_val, decoded_imgs)

# %%
# Test1-2: continue with Lovasz Loss
mt1 = time.time()
model = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
input_x = model.layers[0].input
output_layer = model.layers[-1].input
model = Model(input_x, output_layer)

save_model_name = basic_name + '.model2'
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=2, min_lr=0.00001, verbose=1)
epochs = 30
batch_size = 5
epoch_size = len(x_trn)
lr=0.001
schedule = SGDRScheduler(min_lr=1e-5,
                        max_lr=1e-3,
                        steps_per_epoch=np.ceil(epoch_size/batch_size),
                        lr_decay=0.9,
                        cycle_length=5,
                        mult_factor=1.5)
c = optimizers.adam(lr = lr)
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])
history = model.fit(x_trn, y_trn,
                    validation_data=[x_val, y_val], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[schedule,reduce_lr,model_checkpoint], 
                    verbose=2)
mt2 = time.time()
print(f"Test1-2 {epochs,batch_size} runtime = {(mt2-mt1)/60} mins")
print("Evaluation on X_valid:", model.evaluate(x_valid, y_valid))
# Out:
# Train on 1106 samples, validate on 277 samples
# Epoch 1/30
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.541895). Check your callbacks.
#   % delta_t_median)
#  - 26s - loss: 0.4850 - my_iou_metric_2: 0.0183 - val_loss: 0.4263 - val_my_iou_metric_2: 0.0567
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.05668, saving model to LR_midsurface_v1.2.model2
# Epoch 2/30
#  - 16s - loss: 0.1935 - my_iou_metric_2: 0.0140 - val_loss: 0.1270 - val_my_iou_metric_2: 0.0361
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 3/30
#  - 16s - loss: 0.1405 - my_iou_metric_2: 0.0201 - val_loss: 0.0979 - val_my_iou_metric_2: 0.0191
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.00017601829313207418.
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 4/30
#  - 16s - loss: 0.1190 - my_iou_metric_2: 0.0191 - val_loss: 0.0847 - val_my_iou_metric_2: 0.0278
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 5/30
#  - 16s - loss: 0.1109 - my_iou_metric_2: 0.0165 - val_loss: 0.0858 - val_my_iou_metric_2: 0.0220
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 6/30
#  - 26s - loss: 0.1048 - my_iou_metric_2: 0.0179 - val_loss: 0.0722 - val_my_iou_metric_2: 0.0260
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0004330631927587092.
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 7/30
#  - 19s - loss: 0.0807 - my_iou_metric_2: 0.0189 - val_loss: 0.0590 - val_my_iou_metric_2: 0.0289
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 8/30
#  - 16s - loss: 0.0699 - my_iou_metric_2: 0.0156 - val_loss: 0.0473 - val_my_iou_metric_2: 0.0235
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00031264705467037857.
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 9/30
#  - 20s - loss: 0.0632 - my_iou_metric_2: 0.0161 - val_loss: 0.0476 - val_my_iou_metric_2: 0.0231
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 10/30
#  - 33s - loss: 0.0553 - my_iou_metric_2: 0.0203 - val_loss: 0.0433 - val_my_iou_metric_2: 0.0235
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00014235293201636523.
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 11/30
#  - 25s - loss: 0.0533 - my_iou_metric_2: 0.0234 - val_loss: 0.0437 - val_my_iou_metric_2: 0.0184
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 12/30
#  - 16s - loss: 0.0517 - my_iou_metric_2: 0.0172 - val_loss: 0.0406 - val_my_iou_metric_2: 0.0217
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 2.1936804841971025e-05.
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 13/30
#  - 16s - loss: 0.0512 - my_iou_metric_2: 0.0211 - val_loss: 0.0400 - val_my_iou_metric_2: 0.0242
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 14/30
#  - 16s - loss: 0.0516 - my_iou_metric_2: 0.0202 - val_loss: 0.0455 - val_my_iou_metric_2: 0.0267
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0003981851623393595.
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 15/30
#  - 16s - loss: 0.0492 - my_iou_metric_2: 0.0266 - val_loss: 0.0389 - val_my_iou_metric_2: 0.0242
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 16/30
#  - 16s - loss: 0.0443 - my_iou_metric_2: 0.0277 - val_loss: 0.0393 - val_my_iou_metric_2: 0.0170
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00034642135142348707.
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 17/30
#  - 16s - loss: 0.0448 - my_iou_metric_2: 0.0277 - val_loss: 0.0319 - val_my_iou_metric_2: 0.0375
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 18/30
#  - 16s - loss: 0.0398 - my_iou_metric_2: 0.0314 - val_loss: 0.0349 - val_my_iou_metric_2: 0.0256
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00025676380028016865.
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 19/30
#  - 33s - loss: 0.0365 - my_iou_metric_2: 0.0385 - val_loss: 0.0336 - val_my_iou_metric_2: 0.0260
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 20/30
#  - 29s - loss: 0.0351 - my_iou_metric_2: 0.0385 - val_loss: 0.0295 - val_my_iou_metric_2: 0.0310
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00015323619300033897.
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 21/30
#  - 16s - loss: 0.0340 - my_iou_metric_2: 0.0399 - val_loss: 0.0275 - val_my_iou_metric_2: 0.0451
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 22/30
#  - 20s - loss: 0.0329 - my_iou_metric_2: 0.0420 - val_loss: 0.0262 - val_my_iou_metric_2: 0.0513
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 6.357864185702056e-05.
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 23/30
#  - 32s - loss: 0.0327 - my_iou_metric_2: 0.0382 - val_loss: 0.0276 - val_my_iou_metric_2: 0.0394
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 24/30
#  - 16s - loss: 0.0318 - my_iou_metric_2: 0.0420 - val_loss: 0.0260 - val_my_iou_metric_2: 0.0473
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.181483457912691e-05.
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 25/30
#  - 16s - loss: 0.0318 - my_iou_metric_2: 0.0401 - val_loss: 0.0265 - val_my_iou_metric_2: 0.0430
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 26/30
#  - 16s - loss: 0.0402 - my_iou_metric_2: 0.0321 - val_loss: 0.0360 - val_my_iou_metric_2: 0.0054
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00036176919820718467.
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 27/30
#  - 16s - loss: 0.0353 - my_iou_metric_2: 0.0410 - val_loss: 0.0278 - val_my_iou_metric_2: 0.0469
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.05668
# Epoch 28/30
#  - 16s - loss: 0.0313 - my_iou_metric_2: 0.0511 - val_loss: 0.0239 - val_my_iou_metric_2: 0.0917
#
# Epoch 00028: val_my_iou_metric_2 improved from 0.05668 to 0.09170, saving model to LR_midsurface_v1.2.model2
# Epoch 29/30
#  - 32s - loss: 0.0301 - my_iou_metric_2: 0.0577 - val_loss: 0.0226 - val_my_iou_metric_2: 0.1213
#
# Epoch 00029: val_my_iou_metric_2 improved from 0.09170 to 0.12130, saving model to LR_midsurface_v1.2.model2
# Epoch 30/30
#  - 24s - loss: 0.0309 - my_iou_metric_2: 0.0600 - val_loss: 0.0258 - val_my_iou_metric_2: 0.0780
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.12130
# Test1-2 (30, 5) runtime = 12.89921950896581 mins
# 73/73 [==============================] - 0s 2ms/step
# Evaluation on X_valid: [0.03077443316578865, 0.050684931506849315]

# %%
encoded_imgs = model.predict(x_val)
decoded_imgs = model.predict(encoded_imgs)

plot_results(x_val, decoded_imgs)

# %%
#Test1-2 Performance
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
plt.title('ResUNet: Continue on Lovasz Loss')
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()
plt.title('Cosine annealing learning rate scheduler with periodic restarts')
# Out:
# Text(0.5, 1.0, 'Cosine annealing learning rate scheduler with periodic restarts')

# %%
# Test2-1 -- ResUnet with binary_crossentropy loss
# Without cosine annealing learning rate scheduler with periodic restarts

mt1 = time.time()
save_model_name = basic_name + '.model3'
input_layer = Input((img_size_target, img_size_target, 1))
output_layer = build_model(input_layer, 16,0.25)
model = Model(input_layer, output_layer)

model_checkpoint = ModelCheckpoint(save_model_name,monitor='my_iou_metric', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='my_iou_metric', mode = 'max',factor=0.5, patience=3, min_lr=0.0001, verbose=1)

epochs = 30
batch_size = 5
epoch_size = len(x_trn)
lr=0.01

optimizer = optimizers.adam(lr = lr)
model.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=[my_iou_metric])

history = model.fit(x_trn, y_trn,
                    validation_data=[x_val, y_val], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[reduce_lr, model_checkpoint], 
                    verbose=2)
mt2 = time.time()
print(f"Test2-1 {epochs,batch_size} runtime = {(mt2-mt1)/60} mins")
print("Evaluation on X_valid:", model.evaluate(x_valid, y_valid))
# Out:
# Train on 1106 samples, validate on 277 samples
# Epoch 1/30
#  - 44s - loss: -1.2108e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.1221e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00001: my_iou_metric improved from -inf to 0.00000, saving model to LR_midsurface_v1.2.model3
# Epoch 2/30
#  - 14s - loss: -1.2775e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3415e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00002: my_iou_metric did not improve from 0.00000
# Epoch 3/30
#  - 14s - loss: -1.2837e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3371e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00003: my_iou_metric did not improve from 0.00000
# Epoch 4/30
#  - 14s - loss: -1.2968e+01 - my_iou_metric: 0.0000e+00 - val_loss: -9.9039e+00 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 00004: my_iou_metric did not improve from 0.00000
# Epoch 5/30
#  - 14s - loss: -1.2957e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.2978e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00005: my_iou_metric did not improve from 0.00000
# Epoch 6/30
#  - 14s - loss: -1.2995e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3820e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00006: my_iou_metric did not improve from 0.00000
# Epoch 7/30
#  - 14s - loss: -1.3025e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3839e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 00007: my_iou_metric did not improve from 0.00000
# Epoch 8/30
#  - 14s - loss: -1.3047e+01 - my_iou_metric: 9.0416e-05 - val_loss: -1.3901e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00008: my_iou_metric improved from 0.00000 to 0.00009, saving model to LR_midsurface_v1.2.model3
# Epoch 9/30
#  - 14s - loss: -1.3086e+01 - my_iou_metric: 9.0416e-05 - val_loss: -1.3955e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00009: my_iou_metric did not improve from 0.00009
# Epoch 10/30
#  - 14s - loss: -1.3108e+01 - my_iou_metric: 0.0000e+00 - val_loss: -1.3947e+01 - val_my_iou_metric: 0.0014
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
#
# Epoch 00010: my_iou_metric did not improve from 0.00009
# Epoch 11/30
#  - 14s - loss: -1.3141e+01 - my_iou_metric: 4.5208e-04 - val_loss: -1.3973e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00011: my_iou_metric improved from 0.00009 to 0.00045, saving model to LR_midsurface_v1.2.model3
# Epoch 12/30
#  - 14s - loss: -1.3158e+01 - my_iou_metric: 3.6166e-04 - val_loss: -1.3979e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00012: my_iou_metric did not improve from 0.00045
# Epoch 13/30
#  - 14s - loss: -1.3169e+01 - my_iou_metric: 7.2333e-04 - val_loss: -1.3987e+01 - val_my_iou_metric: 0.0029
#
# Epoch 00013: my_iou_metric improved from 0.00045 to 0.00072, saving model to LR_midsurface_v1.2.model3
# Epoch 14/30
#  - 14s - loss: -1.3168e+01 - my_iou_metric: 8.1374e-04 - val_loss: -1.4019e+01 - val_my_iou_metric: 3.6101e-04
#
# Epoch 00014: my_iou_metric improved from 0.00072 to 0.00081, saving model to LR_midsurface_v1.2.model3
# Epoch 15/30
#  - 14s - loss: -1.3189e+01 - my_iou_metric: 9.0416e-04 - val_loss: -1.4040e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00015: my_iou_metric improved from 0.00081 to 0.00090, saving model to LR_midsurface_v1.2.model3
# Epoch 16/30
#  - 14s - loss: -1.3203e+01 - my_iou_metric: 9.0416e-04 - val_loss: -1.4040e+01 - val_my_iou_metric: 0.0047
#
# Epoch 00016: my_iou_metric did not improve from 0.00090
# Epoch 17/30
#  - 14s - loss: -1.3207e+01 - my_iou_metric: 0.0019 - val_loss: -1.4045e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00017: my_iou_metric improved from 0.00090 to 0.00190, saving model to LR_midsurface_v1.2.model3
# Epoch 18/30
#  - 14s - loss: -1.3204e+01 - my_iou_metric: 0.0012 - val_loss: -1.4035e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00018: my_iou_metric did not improve from 0.00190
# Epoch 19/30
#  - 14s - loss: -1.3211e+01 - my_iou_metric: 0.0026 - val_loss: -1.4062e+01 - val_my_iou_metric: 0.0014
#
# Epoch 00019: my_iou_metric improved from 0.00190 to 0.00262, saving model to LR_midsurface_v1.2.model3
# Epoch 20/30
#  - 14s - loss: -1.3223e+01 - my_iou_metric: 0.0018 - val_loss: -1.4067e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00020: my_iou_metric did not improve from 0.00262
# Epoch 21/30
#  - 21s - loss: -1.3228e+01 - my_iou_metric: 0.0023 - val_loss: -1.4061e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00021: my_iou_metric did not improve from 0.00262
# Epoch 22/30
#  - 24s - loss: -1.3237e+01 - my_iou_metric: 0.0024 - val_loss: -1.4063e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
#
# Epoch 00022: my_iou_metric did not improve from 0.00262
# Epoch 23/30
#  - 24s - loss: -1.3243e+01 - my_iou_metric: 0.0038 - val_loss: -1.4071e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00023: my_iou_metric improved from 0.00262 to 0.00380, saving model to LR_midsurface_v1.2.model3
# Epoch 24/30
#  - 24s - loss: -1.3245e+01 - my_iou_metric: 0.0059 - val_loss: -1.4083e+01 - val_my_iou_metric: 0.0014
#
# Epoch 00024: my_iou_metric improved from 0.00380 to 0.00588, saving model to LR_midsurface_v1.2.model3
# Epoch 25/30
#  - 24s - loss: -1.3253e+01 - my_iou_metric: 0.0061 - val_loss: -1.4091e+01 - val_my_iou_metric: 0.0061
#
# Epoch 00025: my_iou_metric improved from 0.00588 to 0.00615, saving model to LR_midsurface_v1.2.model3
# Epoch 26/30
#  - 24s - loss: -1.3255e+01 - my_iou_metric: 0.0057 - val_loss: -1.4086e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00026: my_iou_metric did not improve from 0.00615
# Epoch 27/30
#  - 24s - loss: -1.3244e+01 - my_iou_metric: 0.0062 - val_loss: -1.4072e+01 - val_my_iou_metric: 0.0061
#
# Epoch 00027: my_iou_metric improved from 0.00615 to 0.00624, saving model to LR_midsurface_v1.2.model3
# Epoch 28/30
#  - 24s - loss: -1.3256e+01 - my_iou_metric: 0.0086 - val_loss: -1.4091e+01 - val_my_iou_metric: 7.2202e-04
#
# Epoch 00028: my_iou_metric improved from 0.00624 to 0.00859, saving model to LR_midsurface_v1.2.model3
# Epoch 29/30
#  - 24s - loss: -1.3257e+01 - my_iou_metric: 0.0076 - val_loss: -1.4079e+01 - val_my_iou_metric: 0.0000e+00
#
# Epoch 00029: my_iou_metric did not improve from 0.00859
# Epoch 30/30
#  - 15s - loss: -1.3258e+01 - my_iou_metric: 0.0076 - val_loss: -1.4099e+01 - val_my_iou_metric: 0.0148
#
# Epoch 00030: my_iou_metric did not improve from 0.00859
# Test2-1 (30, 5) runtime = 12.217860178152721 mins
# 73/73 [==============================] - 0s 2ms/step
# Evaluation on X_valid: [-12.165299938149648, 0.020547945205479454]

# %%
encoded_imgs = model.predict(x_val)
decoded_imgs = model.predict(encoded_imgs)

plot_results(x_val, decoded_imgs)

# %%
#Test2-1 Performance
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
plt.title('ResUNet: Binary Crossentropy Loss')
ax_score.plot(history.epoch, history.history["my_iou_metric"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric"], label="Validation score")
ax_score.legend()
plt.title('Without cosine annealing learning rate scheduler with periodic restarts')
# Out:
# Text(0.5, 1.0, 'Without cosine annealing learning rate scheduler with periodic restarts')

# %%
# Test2-2: continue with Lovasz Loss
mt1 = time.time()
model = load_model(save_model_name,custom_objects={'my_iou_metric': my_iou_metric})
input_x = model.layers[0].input
output_layer = model.layers[-1].input
model = Model(input_x, output_layer)

save_model_name = basic_name + '.model2'
early_stopping = EarlyStopping(monitor='val_my_iou_metric_2', mode = 'max',patience=20, verbose=1)
model_checkpoint = ModelCheckpoint(save_model_name,monitor='val_my_iou_metric_2', 
                                   mode = 'max', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_my_iou_metric_2', mode = 'max',factor=0.5, patience=2, min_lr=0.00001, verbose=1)
epochs = 30
batch_size = 5
epoch_size = len(x_trn)
lr=0.001
c = optimizers.adam(lr = lr)
model.compile(loss=lovasz_loss, optimizer=c, metrics=[my_iou_metric_2])
history = model.fit(x_trn, y_trn,
                    validation_data=[x_val, y_val], 
                    epochs=epochs,
                    batch_size=batch_size,
                    callbacks=[reduce_lr,model_checkpoint], 
                    verbose=2)
mt2 = time.time()
print(f"Test2-2 {epochs,batch_size} runtime = {(mt2-mt1)/60} mins")
print("Evaluation on X_valid:", model.evaluate(x_valid, y_valid))
# Out:
# Train on 1106 samples, validate on 277 samples
# Epoch 1/30
#  - 38s - loss: 0.2594 - my_iou_metric_2: 0.0426 - val_loss: 0.1165 - val_my_iou_metric_2: 0.0834
#
# Epoch 00001: val_my_iou_metric_2 improved from -inf to 0.08339, saving model to LR_midsurface_v1.2.model2
# Epoch 2/30
#  - 16s - loss: 0.0914 - my_iou_metric_2: 0.0321 - val_loss: 0.0694 - val_my_iou_metric_2: 0.0245
#
# Epoch 00002: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 3/30
#  - 16s - loss: 0.0587 - my_iou_metric_2: 0.0369 - val_loss: 0.0426 - val_my_iou_metric_2: 0.0440
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00003: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 4/30
#  - 15s - loss: 0.0484 - my_iou_metric_2: 0.0401 - val_loss: 0.0463 - val_my_iou_metric_2: 0.0256
#
# Epoch 00004: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 5/30
#  - 16s - loss: 0.0741 - my_iou_metric_2: 0.0321 - val_loss: 0.0555 - val_my_iou_metric_2: 0.0451
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00005: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 6/30
#  - 15s - loss: 0.0595 - my_iou_metric_2: 0.0347 - val_loss: 0.0430 - val_my_iou_metric_2: 0.0480
#
# Epoch 00006: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 7/30
#  - 16s - loss: 0.0505 - my_iou_metric_2: 0.0413 - val_loss: 0.0383 - val_my_iou_metric_2: 0.0581
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00007: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 8/30
#  - 16s - loss: 0.0471 - my_iou_metric_2: 0.0422 - val_loss: 0.0380 - val_my_iou_metric_2: 0.0484
#
# Epoch 00008: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 9/30
#  - 16s - loss: 0.0451 - my_iou_metric_2: 0.0455 - val_loss: 0.0355 - val_my_iou_metric_2: 0.0538
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00009: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 10/30
#  - 17s - loss: 0.0435 - my_iou_metric_2: 0.0455 - val_loss: 0.0356 - val_my_iou_metric_2: 0.0444
#
# Epoch 00010: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 11/30
#  - 16s - loss: 0.0429 - my_iou_metric_2: 0.0471 - val_loss: 0.0360 - val_my_iou_metric_2: 0.0437
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00011: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 12/30
#  - 16s - loss: 0.0419 - my_iou_metric_2: 0.0459 - val_loss: 0.0350 - val_my_iou_metric_2: 0.0469
#
# Epoch 00012: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 13/30
#  - 16s - loss: 0.0411 - my_iou_metric_2: 0.0471 - val_loss: 0.0346 - val_my_iou_metric_2: 0.0516
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00013: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 14/30
#  - 16s - loss: 0.0414 - my_iou_metric_2: 0.0525 - val_loss: 0.0342 - val_my_iou_metric_2: 0.0509
#
# Epoch 00014: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 15/30
#  - 16s - loss: 0.0414 - my_iou_metric_2: 0.0446 - val_loss: 0.0341 - val_my_iou_metric_2: 0.0491
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00015: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 16/30
#  - 16s - loss: 0.0399 - my_iou_metric_2: 0.0522 - val_loss: 0.0331 - val_my_iou_metric_2: 0.0560
#
# Epoch 00016: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 17/30
#  - 16s - loss: 0.0404 - my_iou_metric_2: 0.0488 - val_loss: 0.0338 - val_my_iou_metric_2: 0.0495
#
# Epoch 00017: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 18/30
#  - 16s - loss: 0.0400 - my_iou_metric_2: 0.0502 - val_loss: 0.0335 - val_my_iou_metric_2: 0.0498
#
# Epoch 00018: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 19/30
#  - 16s - loss: 0.0396 - my_iou_metric_2: 0.0492 - val_loss: 0.0331 - val_my_iou_metric_2: 0.0505
#
# Epoch 00019: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 20/30
#  - 16s - loss: 0.0403 - my_iou_metric_2: 0.0473 - val_loss: 0.0339 - val_my_iou_metric_2: 0.0473
#
# Epoch 00020: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 21/30
#  - 16s - loss: 0.0389 - my_iou_metric_2: 0.0496 - val_loss: 0.0329 - val_my_iou_metric_2: 0.0527
#
# Epoch 00021: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 22/30
#  - 16s - loss: 0.0392 - my_iou_metric_2: 0.0526 - val_loss: 0.0331 - val_my_iou_metric_2: 0.0505
#
# Epoch 00022: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 23/30
#  - 16s - loss: 0.0386 - my_iou_metric_2: 0.0528 - val_loss: 0.0333 - val_my_iou_metric_2: 0.0495
#
# Epoch 00023: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 24/30
#  - 16s - loss: 0.0388 - my_iou_metric_2: 0.0485 - val_loss: 0.0332 - val_my_iou_metric_2: 0.0480
#
# Epoch 00024: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 25/30
#  - 15s - loss: 0.0392 - my_iou_metric_2: 0.0486 - val_loss: 0.0328 - val_my_iou_metric_2: 0.0516
#
# Epoch 00025: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 26/30
#  - 16s - loss: 0.0386 - my_iou_metric_2: 0.0519 - val_loss: 0.0324 - val_my_iou_metric_2: 0.0527
#
# Epoch 00026: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 27/30
#  - 15s - loss: 0.0381 - my_iou_metric_2: 0.0522 - val_loss: 0.0325 - val_my_iou_metric_2: 0.0509
#
# Epoch 00027: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 28/30
#  - 16s - loss: 0.0383 - my_iou_metric_2: 0.0483 - val_loss: 0.0327 - val_my_iou_metric_2: 0.0484
#
# Epoch 00028: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 29/30
#  - 16s - loss: 0.0387 - my_iou_metric_2: 0.0503 - val_loss: 0.0326 - val_my_iou_metric_2: 0.0469
#
# Epoch 00029: val_my_iou_metric_2 did not improve from 0.08339
# Epoch 30/30
#  - 16s - loss: 0.0377 - my_iou_metric_2: 0.0526 - val_loss: 0.0323 - val_my_iou_metric_2: 0.0513
#
# Epoch 00030: val_my_iou_metric_2 did not improve from 0.08339
# Test2-2 (30, 5) runtime = 12.23024667898814 mins
# 73/73 [==============================] - 0s 2ms/step
# Evaluation on X_valid: [0.03608792076167995, 0.06712328767123288]

# %%
encoded_imgs = model.predict(x_val)
decoded_imgs = model.predict(encoded_imgs)

plot_results(x_val, decoded_imgs)

# %%
#Test2-2 Performance
fig, (ax_loss, ax_score) = plt.subplots(1, 2, figsize=(15,5))
ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
ax_loss.legend()
plt.title('ResUNet: Lavasz Loss')
ax_score.plot(history.epoch, history.history["my_iou_metric_2"], label="Train score")
ax_score.plot(history.epoch, history.history["val_my_iou_metric_2"], label="Validation score")
ax_score.legend()
plt.title('Without cosine annealing learning rate scheduler with periodic restarts')
# Out:
# Text(0.5, 1.0, 'Without cosine annealing learning rate scheduler with periodic restarts')
